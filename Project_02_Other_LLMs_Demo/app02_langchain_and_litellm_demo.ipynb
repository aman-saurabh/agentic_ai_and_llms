# %%
from IPython.display import Markdown
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke("tell_a_joke")

display(Markdown(response.content))
# Out:
# Why don't scientists trust atoms? Because they make up everything.
#
# Want another one (knock-knock, dad joke, or something dark/silly)?

# %%
from litellm import completion
from IPython.display import Markdown, display

response = completion(
    model="openai/gpt-4.1",
    messages=[{"role": "user", "content": "Tell a joke"}]
)

reply = response.choices[0].message["content"]
display(Markdown(reply))
# Out:
# Why did the scarecrow win an award?
#
# Because he was outstanding in his field!

# %%
# With Litellm we can also get the cost of the response, input tokens, output tokens, and total tokens
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 10
# Output tokens: 17
# Total tokens: 27
# Total cost: 0.0156 cents

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(
    model="openai/gpt-4.1",
    messages=question
)

reply = response.choices[0].message["content"]
display(Markdown(reply))
# Out:
# When Laertes asks "Where is my father?" in *Hamlet* (Act 4, Scene 5), Gertrude replies:
#
# **"Dead."**
#
# So, the reply to Laertes' question is: **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 25
# Output tokens: 50
# Total tokens: 75
# Total cost: 0.0450 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="openai/gpt-5-nano", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# The reply is: "Dead." spoken by the King (Claudius). The Queen immediately adds, "But not by him!"—but the direct answer to Laertes’ question is "Dead."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 49685
# Output tokens: 1522
# Total tokens: 51207
# Total cost: 0.0864 cents
